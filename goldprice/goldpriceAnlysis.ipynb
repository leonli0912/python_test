# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime 

from sklearn.linear_model import LinearRegression

df = pd.read_csv("goldprice.csv")
df.head()
# Out:
#           date    price
# 0          NaN      NaN
# 1  31 Dec 2014  1181.33
# 2  30 Dec 2014  1200.35
# 3  29 Dec 2014  1183.02
# 4  26 Dec 2014  1195.82

# %%
df.describe()
x=df["date"]
x0 = pd.to_datetime(x,format='%d %b %Y')
y=df["price"]
plt.plot(x0,y)
plt.show()
