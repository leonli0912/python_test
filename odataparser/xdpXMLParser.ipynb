# %% [markdown]
# # html parser

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('IDCN_BSAIS.XML')

# %%
root = tree.getroot()

for binding in tree.iter('{http://www.xfa.org/schema/xfa-template/2.5/}bind'):
    #if binding.attrib == 'ref':
    print(binding.attrib)
    if binding.attrib['match'] != "none":
        #print('ref:',binding.attrib['ref'])
        ref=binding.attrib['ref']
        nodepath=ref.split('.')
        #print(nodepath)
        field0=nodepath[len(nodepath)-1]        
        prefix=ref[0:ref.rfind(field0)]  
        field=field0.lower().title()

        #print('prefix:',prefix)
        if prefix == 'GS_FORMHDR.':#
            newref = '$.HeaderNode.'+field 
            binding.set('ref',newref)            
        elif prefix == 'GT_FORMLINES_AS.DATA[*].':#GT_FORMLINES_AS.DATA[*].LINETEXT
            newref = '$.HeaderNode.toItemAS.ItemNode_AS[*].'+field
            binding.set('ref',newref)
        elif prefix == 'GT_FORMLINES_LE.DATA[*].':#GT_FORMLINES_LE.DATA[*].LINETEXT
            newref = '$.HeaderNode.toItemLE.ItemNode_LE[*].'+field            
            binding.set('ref',newref)
        elif prefix == 'GT_FORMLINES_PL.DATA[*].':#GT_FORMLINES_PL.DATA[*].LINETEXT
            newref = '$.HeaderNode.toItemPL.ItemNode_PL[*].'+field
            binding.set('ref',newref)
        elif prefix == 'GT_FORMLINES_AS1.DATA[*].':#GT_FORMLINES_AS1.DATA[*].LINETEXT
            newref = '$.HeaderNode.toItemAS.ItemNode_AS[*].'+field
            binding.set('ref',newref)
        elif prefix == 'GT_FORMLINES_LE1.DATA[*].':#GT_FORMLINES_LE1.DATA[*].LINETEXT
            newref = '$.HeaderNode.toItemLE.ItemNode_LE[*].'+field
            binding.set('ref',newref)
       
tree.write('IDCN_BSAIS_xfa2.XML')
    #print(binding.attrib)
# Out:
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.GSBER'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.PRCTR'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.COMPANY'}
# {'match': 'none'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.VPERIOD_D'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.BPERIOD_D'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.BDAY'}
# {'match': 'none'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.VPERIOD_D'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.BPERIOD_D'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.BDAY'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.CURRENCY'}
# {'match': 'none'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_AS.DATA[*].LINETEXT'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_AS.DATA[*].LINENREXT'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_AS.DATA[*].BSUM'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_AS.DATA[*].VSUM'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_LE.DATA[*].LINETEXT'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_LE.DATA[*].LINENREXT'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_LE.DATA[*].BSUM'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_LE.DATA[*].VSUM'}
# {'match': 'none'}
# {'match': 'none'}
# {'match': 'none'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.GSBER'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.PRCTR'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.COMPANY'}
# {'match': 'none'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.VPERIOD_D'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.BPERIOD_D'}
# {'match': 'none'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.VPERIOD_D'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.BPERIOD_D'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.CURRENCY'}
# {'match': 'none'}
# {'match': 'dataRef', 'ref': '$.GV_VSUM_PL'}
# {'match': 'none'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_PL.DATA[*].LINETEXT'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_PL.DATA[*].LINENREXT'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_PL.DATA[*].BSUM'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_PL.DATA[*].VSUM'}
# {'match': 'none'}
# {'match': 'none'}
# {'match': 'none'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.GSBER'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.PRCTR'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.COMPANY'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.CURRENCY'}
# {'match': 'none'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_AS1.DATA[*].LINETEXT'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_AS1.DATA[*].LINENREXT'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_AS1.DATA[*].BSUM'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_AS1.DATA[*].VSUM'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_LE1.DATA[*].LINETEXT'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_LE1.DATA[*].LINENREXT'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_LE1.DATA[*].BSUM'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_LE1.DATA[*].VSUM'}
# {'match': 'none'}
# {'match': 'none'}
# {'match': 'none'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.VPERIOD_D'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.BPERIOD_D'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.BDAY'}
# {'match': 'none'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.VPERIOD_D'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.BPERIOD_D'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.BDAY'}
# {'match': 'none'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.GSBER'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.PRCTR'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.COMPANY'}
# {'match': 'none'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.VPERIOD_D'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.BPERIOD_D'}
# {'match': 'none'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.VPERIOD_D'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.BPERIOD_D'}
# {'match': 'dataRef', 'ref': 'GS_FORMHDR.CURRENCY'}
# {'match': 'dataRef', 'ref': '$.GV_VSUM_PL'}
# {'match': 'none'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_PL1.DATA[*].LINETEXT'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_PL1.DATA[*].LINENREXT'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_PL1.DATA[*].BSUM'}
# {'match': 'dataRef', 'ref': 'GT_FORMLINES_PL1.DATA[*].VSUM'}
# {'match': 'none'}
# {'match': 'none'}
